# %%
import sklearn
import json
import operator
import matplotlib.pyplot as plt
import prettyplotlib as ppl
import seaborn as sns
import numpy as np
from scipy.interpolate import interp1d
sns.set(style='ticks', palette='Set1')
# %matplotlib inline
hist1 = sklearn.externals.joblib.load('agent1_batthistex')
hist2 = sklearn.externals.joblib.load('agent2_batthistex')

# %%
def loader(dictionary):
    def load_keys(k):
        unjsoned = json.loads(k)
        loaded = tuple( ((tuple(unjsoned[0])), unjsoned[1] ))
        return loaded
    return {load_keys(k):v for k,v in dictionary.items()}
def get_score(hist):
    loaded = {k:len(json.loads(v)) for k,v in loader(hist).items()}
    not_running = sum([v for k,v in loaded.items() if k[0][1] == 'sleeping' and k[0][3]=='sleeping'])
    zero = sum([v for k,v in loaded.items() if k[0][0] == 0])
    total = sum([v for k,v in loaded.items()])
    return not_running, zero, total, not_running/total, zero/total
print(get_score(hist1))
print(get_score(hist2))
# Out:
# (2, 0, 10627, 0.00018819986826009222, 0.0)
# (1, 2, 10625, 9.411764705882353e-05, 0.00018823529411764707)

# %%
record = sklearn.externals.joblib.load('batt_exwriter2')
def record_creator(one):
    def grabber(a_record):
        t = a_record[0]
        d = a_record[1]
        return (a_record[0],d['neighbour'])
    return [grabber(i) for i in one]
def record_creator(one):
    def grabber(a_record):
        t = a_record[0]
        d = a_record[1]
        return (a_record[0],d['neighbour'])
    return [grabber(i) for i in one]
one = [(i[0], i[1]['battery']) for i in record if i[1]['_id']==2]
two = record_creator([i for i in record if i[1]['_id']==2])
#two = [(i[0], i[1]['battery']) for i in record if i[1]['_id']==3]

# %%
fig,ax = plt.subplots(1)
#one_plot = one[1083:1120]
#two_plot = two[1083:1120]
one_plot = one[9445:9475]
two_plot = two[9445:9475]
x1 = [e[0]+0.3*i for i,e in enumerate(one_plot)]
one_smooth = interp1d(x1, [i[1] for i in one_plot], kind='cubic')
xnew = np.linspace(x1[0], x1[-1], 100)
y1 =  [e[0]+0.3*i for i,e in enumerate(two_plot)]
ppl.plot(ax, x1,[i[1] for i in one_plot], label = 'Sensor 1', linewidth = 1.25  )
ppl.plot(ax, y1,[i[1] for i in two_plot], label = 'Sensor 2', linewidth = 1.25 )
ax.set_ylim([0,4])
ax.set_xlim([x1[0],x1[-1]])
ax.set_ylabel('Battery')
ax.set_xlabel('t')
ax.set_xticks([])
ax.set_yticks(range(5))
legend = plt.legend()
ax.spines['bottom'].set_visible(False)
fig.savefig('learned', format = 'svg')
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
agent1 = sklearn.externals.joblib.load('agent1_battex')
loader(agent1)
# Out:
# {((0, 'pending', 0, 'pending'), 'go_to_sleep'): 12.589990801873126,
#  ((0, 'pending', 0, 'sleeping'), 'go_to_sleep'): 680.2255295753698,
#  ((0, 'pending', 1, 'pending'), 'go_to_sleep'): 753.6737796678021,
#  ((0, 'pending', 1, 'running'), 'go_to_sleep'): 4.213684891307473,
#  ((0, 'pending', 1, 'sleeping'), 'go_to_sleep'): 1045.864658569014,
#  ((0, 'pending', 2, 'pending'), 'go_to_sleep'): -46.63705395097458,
#  ((0, 'pending', 2, 'running'), 'go_to_sleep'): 405.3279454899461,
#  ((0, 'pending', 2, 'sleeping'), 'go_to_sleep'): 313.96331628380295,
#  ((0, 'pending', 3, 'pending'), 'go_to_sleep'): -100,
#  ((0, 'pending', 3, 'running'), 'go_to_sleep'): 834.6572671065913,
#  ((0, 'pending', 3, 'sleeping'), 'go_to_sleep'): 885.6186973611614,
#  ((0, 'pending', 4, 'running'), 'go_to_sleep'): 397.83745844455007,
#  ((0, 'pending', 5, 'sleeping'), 'go_to_sleep'): -100.0,
#  ((0, 'sleeping', 0, 'pending'), 'noop'): 335.31677460489334,
#  ((0, 'sleeping', 0, 'pending'), 'wakeup'): 19.711410572926567,
#  ((0, 'sleeping', 0, 'sleeping'), 'noop'): 363.7765519866991,
#  ((0, 'sleeping', 0, 'sleeping'), 'wakeup'): 67.04565413672685,
#  ((0, 'sleeping', 1, 'pending'), 'noop'): 942.5312356088026,
#  ((0, 'sleeping', 1, 'pending'), 'wakeup'): 90,
#  ((0, 'sleeping', 1, 'running'), 'noop'): 249.56898860100802,
#  ((0, 'sleeping', 1, 'running'), 'wakeup'): -13.290963114872993,
#  ((0, 'sleeping', 1, 'sleeping'), 'noop'): 1118.9509582613584,
#  ((0, 'sleeping', 1, 'sleeping'), 'wakeup'): 303.5476714164532,
#  ((0, 'sleeping', 2, 'pending'), 'noop'): 0,
#  ((0, 'sleeping', 2, 'pending'), 'wakeup'): 335.72167573187096,
#  ((0, 'sleeping', 2, 'running'), 'noop'): 1311.0669629794509,
#  ((0, 'sleeping', 2, 'running'), 'wakeup'): 532.5653288208591,
#  ((0, 'sleeping', 2, 'sleeping'), 'noop'): 738.3438772684949,
#  ((0, 'sleeping', 3, 'running'), 'noop'): 746.7648278776519,
#  ((0, 'sleeping', 3, 'running'), 'wakeup'): 264.5724883393789,
#  ((0, 'sleeping', 3, 'sleeping'), 'noop'): 493.4153534080075,
#  ((0, 'sleeping', 3, 'sleeping'), 'wakeup'): 90,
#  ((0, 'sleeping', 4, 'running'), 'noop'): 1280.5596574563583,
#  ((0, 'sleeping', 4, 'running'), 'wakeup'): 90,
#  ((0, 'sleeping', 4, 'sleeping'), 'noop'): 100,
#  ((0, 'sleeping', 4, 'sleeping'), 'wakeup'): 90,
#  ((0, 'sleeping', 5, 'running'), 'noop'): 20.0,
#  ((1, 'pending', 0, 'pending'), 'go_to_sleep'): 265.6808763531378,
#  ((1, 'pending', 0, 'sleeping'), 'go_to_sleep'): 1389.731584460445,
#  ((1, 'pending', 1, 'pending'), 'go_to_sleep'): 1370.0814741107533,
#  ((1, 'pending', 1, 'running'), 'go_to_sleep'): 764.5613150441625,
#  ((1, 'pending', 1, 'sleeping'), 'go_to_sleep'): 1121.337921692039,
#  ((1, 'pending', 2, 'pending'), 'go_to_sleep'): 925.0393201838247,
#  ((1, 'pending', 2, 'running'), 'go_to_sleep'): 1372.0989630559577,
#  ((1, 'pending', 2, 'sleeping'), 'go_to_sleep'): 7415.672096821636,
#  ((1, 'pending', 3, 'pending'), 'go_to_sleep'): 580.3436063232707,
#  ((1, 'pending', 3, 'running'), 'go_to_sleep'): 927.3472542575396,
#  ((1, 'pending', 3, 'sleeping'), 'go_to_sleep'): 217.20560586542297,
#  ((1, 'pending', 4, 'running'), 'go_to_sleep'): 1494.5762877855475,
#  ((1, 'pending', 4, 'sleeping'), 'go_to_sleep'): 426.55730473821905,
#  ((1, 'pending', 5, 'running'), 'go_to_sleep'): 433.68501798893806,
#  ((1, 'running', 0, 'pending'), 'noop'): 369.7807466237885,
#  ((1, 'running', 0, 'pending'), 'prep_sleep'): 25.69317640322086,
#  ((1, 'running', 0, 'sleeping'), 'noop'): -55.43938383022865,
#  ((1, 'running', 0, 'sleeping'), 'prep_sleep'): 512.6164561813628,
#  ((1, 'running', 1, 'pending'), 'noop'): 860.3723159138359,
#  ((1, 'running', 1, 'pending'), 'prep_sleep'): 179.91223618574185,
#  ((1, 'running', 1, 'running'), 'noop'): -101.58567661977057,
#  ((1, 'running', 1, 'running'), 'prep_sleep'): -122.85998158394464,
#  ((1, 'running', 1, 'sleeping'), 'noop'): -11.949358674829092,
#  ((1, 'running', 1, 'sleeping'), 'prep_sleep'): 200.75496989989884,
#  ((1, 'running', 2, 'pending'), 'noop'): -100,
#  ((1, 'running', 2, 'pending'), 'prep_sleep'): 18.645406635305427,
#  ((1, 'running', 2, 'running'), 'noop'): 479.0915871456073,
#  ((1, 'running', 2, 'running'), 'prep_sleep'): 118.70830079526907,
#  ((1, 'running', 2, 'sleeping'), 'noop'): 559.223895519496,
#  ((1, 'running', 2, 'sleeping'), 'prep_sleep'): 749.892910771059,
#  ((1, 'running', 3, 'pending'), 'noop'): -100,
#  ((1, 'running', 3, 'pending'), 'prep_sleep'): -100,
#  ((1, 'running', 3, 'running'), 'noop'): -100.0,
#  ((1, 'running', 3, 'running'), 'prep_sleep'): 169.34740578408181,
#  ((1, 'running', 3, 'sleeping'), 'noop'): 46.016136314808605,
#  ((1, 'running', 3, 'sleeping'), 'prep_sleep'): -100,
#  ((1, 'running', 4, 'running'), 'noop'): 7.584130581630532,
#  ((1, 'running', 4, 'running'), 'prep_sleep'): 468.87692641122436,
#  ((1, 'running', 5, 'running'), 'noop'): -5.655925515733536,
#  ((1, 'running', 5, 'running'), 'prep_sleep'): -100.49657802590873,
#  ((1, 'running', 5, 'sleeping'), 'noop'): -100,
#  ((1, 'running', 5, 'sleeping'), 'prep_sleep'): -100,
#  ((1, 'sleeping', 0, 'pending'), 'noop'): 119.98856173297067,
#  ((1, 'sleeping', 0, 'pending'), 'wakeup'): 850.5642986382785,
#  ((1, 'sleeping', 0, 'sleeping'), 'noop'): 614.4890115070524,
#  ((1, 'sleeping', 1, 'pending'), 'noop'): 874.1394211178007,
#  ((1, 'sleeping', 1, 'pending'), 'wakeup'): 1457.1123199981346,
#  ((1, 'sleeping', 1, 'running'), 'noop'): 154.27855092543217,
#  ((1, 'sleeping', 1, 'running'), 'wakeup'): 1184.4591809404737,
#  ((1, 'sleeping', 1, 'sleeping'), 'noop'): 1367.7266752448452,
#  ((1, 'sleeping', 1, 'sleeping'), 'wakeup'): 1021.71488083358,
#  ((1, 'sleeping', 2, 'pending'), 'noop'): 0,
#  ((1, 'sleeping', 2, 'pending'), 'wakeup'): 434.25863027019744,
#  ((1, 'sleeping', 2, 'running'), 'noop'): 571.9424914267909,
#  ((1, 'sleeping', 2, 'running'), 'wakeup'): 1139.7094162561773,
#  ((1, 'sleeping', 2, 'sleeping'), 'noop'): 699.3659377200091,
#  ((1, 'sleeping', 2, 'sleeping'), 'wakeup'): 1169.626901376006,
#  ((1, 'sleeping', 3, 'pending'), 'noop'): 0,
#  ((1, 'sleeping', 3, 'pending'), 'wakeup'): 701.4043823627339,
#  ((1, 'sleeping', 3, 'running'), 'noop'): 7399.924428595071,
#  ((1, 'sleeping', 3, 'running'), 'wakeup'): 1241.686289183687,
#  ((1, 'sleeping', 3, 'sleeping'), 'noop'): 655.8607713840719,
#  ((1, 'sleeping', 3, 'sleeping'), 'wakeup'): 893.1315300549062,
#  ((1, 'sleeping', 4, 'pending'), 'wakeup'): 90,
#  ((1, 'sleeping', 4, 'running'), 'noop'): 137.17805769789044,
#  ((1, 'sleeping', 4, 'running'), 'wakeup'): 1137.598341464867,
#  ((1, 'sleeping', 4, 'sleeping'), 'noop'): 100,
#  ((1, 'sleeping', 5, 'running'), 'noop'): 0,
#  ((1, 'sleeping', 5, 'running'), 'wakeup'): 710.2062439919702,
#  ((1, 'sleeping', 5, 'sleeping'), 'noop'): 186.75953438929446,
#  ((2, 'pending', 0, 'pending'), 'go_to_sleep'): 468.31681185381404,
#  ((2, 'pending', 0, 'sleeping'), 'go_to_sleep'): 59.67665238933668,
#  ((2, 'pending', 1, 'pending'), 'go_to_sleep'): 35.058157193858776,
#  ((2, 'pending', 1, 'running'), 'go_to_sleep'): 56.77826909087959,
#  ((2, 'pending', 1, 'sleeping'), 'go_to_sleep'): 1247.0175187142727,
#  ((2, 'pending', 2, 'pending'), 'go_to_sleep'): -10,
#  ((2, 'pending', 2, 'running'), 'go_to_sleep'): 405.5900090565963,
#  ((2, 'pending', 2, 'sleeping'), 'go_to_sleep'): -10,
#  ((2, 'pending', 3, 'pending'), 'go_to_sleep'): -10,
#  ((2, 'pending', 3, 'running'), 'go_to_sleep'): 747.4653069343921,
#  ((2, 'pending', 3, 'sleeping'), 'go_to_sleep'): 705.0684335355966,
#  ((2, 'pending', 4, 'running'), 'go_to_sleep'): 207.58444364389695,
#  ((2, 'pending', 4, 'sleeping'), 'go_to_sleep'): -10.0,
#  ((2, 'running', 0, 'pending'), 'noop'): 217.0231013587118,
#  ((2, 'running', 0, 'pending'), 'prep_sleep'): 1365.7371813916225,
#  ((2, 'running', 0, 'sleeping'), 'noop'): 100.54493551300422,
#  ((2, 'running', 0, 'sleeping'), 'prep_sleep'): 1106.635657641897,
#  ((2, 'running', 1, 'pending'), 'noop'): 214.84635133011412,
#  ((2, 'running', 1, 'pending'), 'prep_sleep'): 1190.4624293145857,
#  ((2, 'running', 1, 'running'), 'noop'): 360.40918723141914,
#  ((2, 'running', 1, 'running'), 'prep_sleep'): 28.635720255480486,
#  ((2, 'running', 1, 'sleeping'), 'noop'): 756.633024501205,
#  ((2, 'running', 1, 'sleeping'), 'prep_sleep'): 7331.31282142764,
#  ((2, 'running', 2, 'pending'), 'noop'): 144.75611745320384,
#  ((2, 'running', 2, 'pending'), 'prep_sleep'): 1139.2408494430174,
#  ((2, 'running', 2, 'running'), 'noop'): 589.7471417952011,
#  ((2, 'running', 2, 'running'), 'prep_sleep'): 1336.3338445452405,
#  ((2, 'running', 2, 'sleeping'), 'noop'): 52.22374323219178,
#  ((2, 'running', 2, 'sleeping'), 'prep_sleep'): 529.0743612958274,
#  ((2, 'running', 3, 'running'), 'noop'): 329.7039289452811,
#  ((2, 'running', 3, 'running'), 'prep_sleep'): 1396.958036619676,
#  ((2, 'running', 3, 'sleeping'), 'noop'): 312.16615251082936,
#  ((2, 'running', 3, 'sleeping'), 'prep_sleep'): 1425.2976886237618,
#  ((2, 'running', 4, 'running'), 'noop'): 133.5301057002001,
#  ((2, 'running', 4, 'running'), 'prep_sleep'): 965.9227980654666,
#  ((2, 'running', 4, 'sleeping'), 'noop'): 32.697814414550166,
#  ((2, 'running', 4, 'sleeping'), 'prep_sleep'): 243.15557724145688,
#  ((2, 'running', 5, 'running'), 'noop'): 107.77459395792346,
#  ((2, 'running', 5, 'running'), 'prep_sleep'): 120.13162612825747,
#  ((2, 'running', 5, 'sleeping'), 'noop'): 100,
#  ((2, 'sleeping', 0, 'pending'), 'noop'): 98.76427714111838,
#  ((2, 'sleeping', 0, 'pending'), 'wakeup'): 437.024335938975,
#  ((2, 'sleeping', 0, 'sleeping'), 'noop'): 169.77217990753104,
#  ((2, 'sleeping', 0, 'sleeping'), 'wakeup'): 951.5899230749233,
#  ((2, 'sleeping', 1, 'pending'), 'noop'): 433.2374697468994,
#  ((2, 'sleeping', 1, 'pending'), 'wakeup'): 852.2372022944603,
#  ((2, 'sleeping', 1, 'running'), 'wakeup'): 459.8081068018143,
#  ((2, 'sleeping', 1, 'sleeping'), 'noop'): 148.98338426787495,
#  ((2, 'sleeping', 1, 'sleeping'), 'wakeup'): 1211.639441530315,
#  ((2, 'sleeping', 2, 'pending'), 'noop'): 49.81077422181011,
#  ((2, 'sleeping', 2, 'pending'), 'wakeup'): 1520.0195492285654,
#  ((2, 'sleeping', 2, 'running'), 'noop'): 918.8993069840103,
#  ((2, 'sleeping', 2, 'running'), 'wakeup'): 7373.916576345262,
#  ((2, 'sleeping', 2, 'sleeping'), 'noop'): 795.3132815476216,
#  ((2, 'sleeping', 2, 'sleeping'), 'wakeup'): 1300.8707429850133,
#  ((2, 'sleeping', 3, 'pending'), 'wakeup'): 122.47130466197788,
#  ((2, 'sleeping', 3, 'running'), 'noop'): 45.45796791296,
#  ((2, 'sleeping', 3, 'running'), 'wakeup'): 892.2592073461974,
#  ((2, 'sleeping', 3, 'sleeping'), 'noop'): 125.52019208,
#  ((2, 'sleeping', 4, 'pending'), 'wakeup'): 90,
#  ((2, 'sleeping', 4, 'running'), 'noop'): 915.6824627798085,
#  ((2, 'sleeping', 4, 'running'), 'wakeup'): 90,
#  ((2, 'sleeping', 4, 'sleeping'), 'wakeup'): 90,
#  ((2, 'sleeping', 5, 'running'), 'wakeup'): 128.97321811603146,
#  ((2, 'sleeping', 5, 'sleeping'), 'noop'): 100,
#  ((2, 'sleeping', 5, 'sleeping'), 'wakeup'): 90,
#  ((3, 'pending', 0, 'sleeping'), 'go_to_sleep'): 151.02554699887975,
#  ((3, 'pending', 1, 'pending'), 'go_to_sleep'): 90.82676073036373,
#  ((3, 'pending', 1, 'running'), 'go_to_sleep'): -10,
#  ((3, 'pending', 2, 'pending'), 'go_to_sleep'): -10,
#  ((3, 'pending', 2, 'running'), 'go_to_sleep'): 511.57071412200844,
#  ((3, 'pending', 2, 'sleeping'), 'go_to_sleep'): 621.2817091009136,
#  ((3, 'pending', 3, 'running'), 'go_to_sleep'): 58.076,
#  ((3, 'pending', 4, 'pending'), 'go_to_sleep'): 82.19870458546953,
#  ((3, 'pending', 4, 'running'), 'go_to_sleep'): 705.7503519248565,
#  ((3, 'running', 0, 'pending'), 'noop'): 759.6016710591566,
#  ((3, 'running', 0, 'pending'), 'prep_sleep'): -13.564,
#  ((3, 'running', 0, 'sleeping'), 'noop'): 931.0626570222569,
#  ((3, 'running', 0, 'sleeping'), 'prep_sleep'): 76.7454760199618,
#  ((3, 'running', 1, 'pending'), 'noop'): 7357.7469220961975,
#  ((3, 'running', 1, 'pending'), 'prep_sleep'): 1152.1449594872784,
#  ((3, 'running', 1, 'running'), 'noop'): 1391.1142070976687,
#  ((3, 'running', 1, 'running'), 'prep_sleep'): 155.08497317672243,
#  ((3, 'running', 1, 'sleeping'), 'noop'): 1033.1021857620362,
#  ((3, 'running', 1, 'sleeping'), 'prep_sleep'): 160.65714405088613,
#  ((3, 'running', 2, 'pending'), 'noop'): 120.01357583057745,
#  ((3, 'running', 2, 'pending'), 'prep_sleep'): -10,
#  ((3, 'running', 2, 'running'), 'noop'): 917.1165638862716,
#  ((3, 'running', 2, 'running'), 'prep_sleep'): 70.24082517291758,
#  ((3, 'running', 2, 'sleeping'), 'noop'): 1462.1499513265683,
#  ((3, 'running', 2, 'sleeping'), 'prep_sleep'): 411.7981960735616,
#  ((3, 'running', 3, 'pending'), 'noop'): 100,
#  ((3, 'running', 3, 'running'), 'noop'): 1277.1090518911271,
#  ((3, 'running', 3, 'running'), 'prep_sleep'): 223.44473900477365,
#  ((3, 'running', 3, 'sleeping'), 'noop'): 362.4124370226644,
#  ((3, 'running', 3, 'sleeping'), 'prep_sleep'): 165.64433522578145,
#  ((3, 'running', 4, 'pending'), 'noop'): 100,
#  ((3, 'running', 4, 'pending'), 'prep_sleep'): -10,
#  ((3, 'running', 4, 'running'), 'noop'): 100,
#  ((3, 'running', 4, 'running'), 'prep_sleep'): 199.3292417336017,
#  ((3, 'running', 4, 'sleeping'), 'noop'): 119.8,
#  ((3, 'running', 5, 'sleeping'), 'noop'): 100.0,
#  ((3, 'sleeping', 0, 'pending'), 'noop'): 0,
#  ((3, 'sleeping', 0, 'sleeping'), 'wakeup'): 303.8250950962184,
#  ((3, 'sleeping', 1, 'pending'), 'noop'): 196.70320111826624,
#  ((3, 'sleeping', 1, 'pending'), 'wakeup'): 1260.2245099830623,
#  ((3, 'sleeping', 1, 'running'), 'noop'): 27.194172991729978,
#  ((3, 'sleeping', 1, 'running'), 'wakeup'): 608.6783823717997,
#  ((3, 'sleeping', 1, 'sleeping'), 'noop'): 117.82,
#  ((3, 'sleeping', 1, 'sleeping'), 'wakeup'): 790.58390252532,
#  ((3, 'sleeping', 2, 'pending'), 'noop'): 0,
#  ((3, 'sleeping', 2, 'pending'), 'wakeup'): 90,
#  ((3, 'sleeping', 2, 'running'), 'wakeup'): 157.52673460404498,
#  ((3, 'sleeping', 2, 'sleeping'), 'wakeup'): 262.53820455512334,
#  ((3, 'sleeping', 3, 'pending'), 'noop'): 17.82,
#  ((3, 'sleeping', 3, 'pending'), 'wakeup'): 171.14762330679986,
#  ((3, 'sleeping', 3, 'running'), 'noop'): 89.80583014808514,
#  ((3, 'sleeping', 3, 'running'), 'wakeup'): 1248.795308406979,
#  ((3, 'sleeping', 3, 'sleeping'), 'wakeup'): 90,
#  ((3, 'sleeping', 4, 'running'), 'wakeup'): 140.97957504011177,
#  ((3, 'sleeping', 4, 'sleeping'), 'noop'): 100,
#  ((3, 'sleeping', 4, 'sleeping'), 'wakeup'): 121.4008088040364,
#  ((3, 'sleeping', 5, 'running'), 'wakeup'): 90,
#  ((4, 'pending', 1, 'running'), 'go_to_sleep'): 73.92170580578401,
#  ((4, 'pending', 1, 'sleeping'), 'go_to_sleep'): 115.7776,
#  ((4, 'pending', 2, 'running'), 'go_to_sleep'): 90,
#  ((4, 'pending', 3, 'running'), 'go_to_sleep'): 126.08171343598754,
#  ((4, 'pending', 3, 'sleeping'), 'go_to_sleep'): -10,
#  ((4, 'running', 0, 'pending'), 'noop'): 783.8683971949002,
#  ((4, 'running', 0, 'pending'), 'prep_sleep'): 56.60427992546605,
#  ((4, 'running', 0, 'sleeping'), 'noop'): 100,
#  ((4, 'running', 1, 'pending'), 'noop'): 248.96529192038903,
#  ((4, 'running', 1, 'running'), 'noop'): 142.76098747340865,
#  ((4, 'running', 1, 'sleeping'), 'noop'): 1383.2381406676036,
#  ((4, 'running', 1, 'sleeping'), 'prep_sleep'): 343.3453316982035,
#  ((4, 'running', 2, 'pending'), 'noop'): 703.7038805901519,
#  ((4, 'running', 2, 'pending'), 'prep_sleep'): -10,
#  ((4, 'running', 2, 'running'), 'noop'): 1396.211133832185,
#  ((4, 'running', 2, 'running'), 'prep_sleep'): 4.02,
#  ((4, 'running', 2, 'sleeping'), 'prep_sleep'): 88.02,
#  ((4, 'running', 3, 'running'), 'noop'): 623.2430909821627,
#  ((4, 'running', 3, 'running'), 'prep_sleep'): 127.73464410239848,
#  ((4, 'running', 3, 'sleeping'), 'prep_sleep'): 476.26153362585876,
#  ((4, 'running', 4, 'pending'), 'noop'): 100,
#  ((4, 'running', 4, 'running'), 'prep_sleep'): 90,
#  ((4, 'running', 4, 'sleeping'), 'noop'): 100,
#  ((4, 'running', 5, 'running'), 'prep_sleep'): 255.1032732960754,
#  ((4, 'sleeping', 0, 'pending'), 'wakeup'): 144.70175086575648,
#  ((4, 'sleeping', 0, 'sleeping'), 'wakeup'): 90,
#  ((4, 'sleeping', 1, 'running'), 'wakeup'): 90,
#  ((4, 'sleeping', 1, 'sleeping'), 'noop'): 37.82,
#  ((4, 'sleeping', 1, 'sleeping'), 'wakeup'): 310.46889130954105,
#  ((4, 'sleeping', 2, 'pending'), 'wakeup'): 148.5691265852271,
#  ((4, 'sleeping', 2, 'running'), 'noop'): 82.822688,
#  ((4, 'sleeping', 2, 'running'), 'wakeup'): 202.11931882237351,
#  ((4, 'sleeping', 2, 'sleeping'), 'noop'): 103.96,
#  ((4, 'sleeping', 3, 'sleeping'), 'wakeup'): 107.82,
#  ((4, 'sleeping', 4, 'sleeping'), 'noop'): 100,
#  ((4, 'sleeping', 5, 'running'), 'wakeup'): 90,
#  ((5, 'running', 0, 'pending'), 'noop'): 100,
#  ((5, 'running', 0, 'sleeping'), 'noop'): 122.2659316,
#  ((5, 'running', 0, 'sleeping'), 'prep_sleep'): 95.72572887717426,
#  ((5, 'running', 1, 'pending'), 'noop'): 429.4040332724562,
#  ((5, 'running', 1, 'pending'), 'prep_sleep'): -10,
#  ((5, 'running', 1, 'running'), 'noop'): 252.04662039365488,
#  ((5, 'running', 1, 'sleeping'), 'noop'): 100,
#  ((5, 'running', 2, 'running'), 'prep_sleep'): 90,
#  ((5, 'running', 2, 'sleeping'), 'noop'): 316.37359064063105,
#  ((5, 'running', 2, 'sleeping'), 'prep_sleep'): 95.003048,
#  ((5, 'running', 3, 'running'), 'prep_sleep'): 90,
#  ((5, 'running', 4, 'pending'), 'noop'): 100,
#  ((5, 'running', 4, 'running'), 'prep_sleep'): 107.38836,
#  ((5, 'running', 4, 'sleeping'), 'noop'): 100,
#  ((5, 'running', 5, 'running'), 'wakeup'): 131.1101878907128,
#  ((5, 'sleeping', 0, 'pending'), 'noop'): 0,
#  ((5, 'sleeping', 0, 'pending'), 'wakeup'): 118.45285775656981,
#  ((5, 'sleeping', 0, 'sleeping'), 'wakeup'): 90,
#  ((5, 'sleeping', 1, 'pending'), 'noop'): 0,
#  ((5, 'sleeping', 1, 'running'), 'noop'): 34.89073705244161,
#  ((5, 'sleeping', 1, 'sleeping'), 'noop'): 100,
#  ((5, 'sleeping', 2, 'pending'), 'wakeup'): 118.11744151793545,
#  ((5, 'sleeping', 2, 'running'), 'wakeup'): 133.6952347640446,
#  ((5, 'sleeping', 2, 'sleeping'), 'noop'): 100,
#  ((5, 'sleeping', 2, 'sleeping'), 'wakeup'): 90,
#  ((5, 'sleeping', 3, 'running'), 'noop'): 33.82,
#  ((5, 'sleeping', 4, 'pending'), 'wakeup'): 90,
#  ((5, 'sleeping', 5, 'running'), 'noop'): 0}

# %%
record[9000::]
# Out:
# [(36.20084573799977,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.210174861997075,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.21108337800251,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.21158416900289,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.21240959900024,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.212906763998035,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.230036501998256,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.23057173899724,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.2340403049966,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.234576315000595,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.240264412001125,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.2408114380014,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.24163571900135,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.24212352599716,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.26014536499861,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.26069394899969,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.26161279700318,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.26208430700353,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.262844980999944,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.272238937999646,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.27332659599779,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.27384541199717,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.281335129999206,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.29083485400042,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.2917500370022,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.292235166001774,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.293025402999774,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.29352580200066,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.29780379799922,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.29832129099668,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.29952578999655,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.300240732998645,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.32177660299931,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.32229717999871,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.323076225002296,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.32356603699736,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.32660198699887,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.32740935200127,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.32824913800141,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.32870521100267,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.32960508399992,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.35185779000312,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.35271039699728,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.35319081800117,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.35396610599855,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.357990994998545,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.358965350998915,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.35947917299927,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.3602656410003,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.36073516000033,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.38326579400018,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.38384963099816,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.38468995499716,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.38514628000121,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.392005995003274,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.39256383199972,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.39345524500095,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.39395627100021,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.412796514996444,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.41336131100252,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.414249977999134,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.41472529600287,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.41581035099807,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.42092169800162,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.42185548099951,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.42237893000129,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.423253337998176,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.443544727997505,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.4444360790003,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.44488013299997,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.44578591699974,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.44627192200278,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.45157352300157,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.45211368799937,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.45295541299856,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.45347709499765,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.47437933600304,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.47489873300219,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.47566806100076,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.476101430998824,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.48472464999941,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.48535140400054,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.48617822000233,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.48665687099856,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.487465587997576,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.504604209003446,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.5055001590008,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.50596917600342,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.50671747099841,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.50951159300166,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.51076307299809,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.51126872999885,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.512051103003614,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.51252570199722,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.53504858099768,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.5355712620003,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.53638470399892,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.536849110998446,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.540524636002374,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.541194256999006,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.54209364300186,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.54259482699854,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.56550368900207,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.56601307899837,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.56680986900028,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.56728374300292,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.56808211599855,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.57368301400129,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.574587014001736,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.57505221400061,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.57593854700099,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.595837913999276,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.59673545300029,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.597210375999566,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.59799237999687,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.59847801899741,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.60156434500095,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.60211172999698,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.60313776299881,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.60381208900071,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.62650250599836,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.6270187639966,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.62781363799877,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.62827793299948,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.63178408599924,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.6329340059965,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.63389213600021,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.634402586998476,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.635176488998695,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.656504329999734,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.65748186199926,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.657949622996966,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.65869598399877,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.6616652369994,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.66280764200201,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.66332234800211,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.66416423299961,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.6646596540013,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.687547004003136,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.68805945000349,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.68893328300328,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.68940840900177,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.693972223001765,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.69450739600143,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.69533521399717,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.69581817300059,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.7177716820006,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.718352160001814,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.71912250800233,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.719565042003524,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.720451471999695,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.726327183998364,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.72724478899909,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.72776224699919,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.72855111499666,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.749654500999895,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.752300731001014,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.75499404400034,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.75652022600116,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.75879235799948,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.763007248002395,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.76354076900316,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.764312528997834,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.76477073899878,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.78207995199773,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.78261387100065,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.783446693996666,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.78392201800307,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.78989229499712,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.790823454997735,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.79180133299815,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.79228889999649,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.793474687001435,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.81237879599939,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.81327303600119,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.81377125799918,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.81595589600329,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.81866347599862,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.82010992299911,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.82076893700287,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.82165913600329,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.82212397800322,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.84436540400202,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.84506771800079,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.8459363869988,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.84642332600197,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.853868478996446,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.85447996300354,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.85526443800336,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.85770303699974,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.87508950800111,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.877201807001256,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.879737258001114,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.88021690300229,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.883019932000025,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.884136031003436,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.88499527300155,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.88547221400222,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.89318582400301,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.89372318799724,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.9084328329991,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.90899898100179,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.90977657100302,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.91193494899926,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.913617475001956,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.91412717800267,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.91494832099852,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.915423272002954,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.93610524699761,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.936977195997315,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.93790335799713,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.93837920600345,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.944047602002684,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.944662961002905,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.945770061000076,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.94633638700179,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.94713481100189,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.966995201997634,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.96790034999867,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.968352147996484,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.96930593399884,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (36.97019414600072,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.97624779000034,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (36.977002977000666,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (36.9780850169991,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (36.98294916199666,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.00049127799866,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.00170048199652,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.00538611599768,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.007847170003515,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.01130559000012,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.011856185003126,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.01940504000231,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.020320638002886,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.02929271099856,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.03117734799889,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.03207111499796,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.03254858699802,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.03431730400189,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.036566568000126,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.03759612399881,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.038066920002166,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.04368723699736,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.04437121399678,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.059345152003516,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.06020946300123,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.06112179900083,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.06161242900271,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.06409902800078,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.064607957996486,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.06547347400192,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.06593144899671,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.087098876996606,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.0876150030017,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.0884123279975,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.088880689996586,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.095773663997534,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.09654676700302,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.097350552001444,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.09781642600137,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.09865603700018,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.117371159998584,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.1182726679981,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.11873665999883,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.11963163800101,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.12027318299806,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.124975416998495,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.12551126300241,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.12629119600024,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.12689547199989,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.14761587300018,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.148120395999285,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.148966838998604,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.14943915900221,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.15410030900239,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.154640202003065,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.15545753599872,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.1559180309996,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.17779775799863,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.17844021700148,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.17937243299821,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.18044190300134,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.18124598600116,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.186558444002,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.18744608599809,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.1879239780028,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.18873549300042,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.18920463100221,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.20901810000214,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.20951821200288,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.21039432100224,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.21086515799834,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.21747012100241,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.2180052650001,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.21884520599997,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.21939722100069,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.240538721998746,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.24110013299651,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.24285505500302,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.24431781400199,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.25298290199862,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.253566346997104,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.2544012119979,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.2548887869998,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.25870018899877,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.273362672000076,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.27828367299662,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.28162882600009,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.28424129499763,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.28528601700236,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.29307893299847,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.293629250001686,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.30665938099992,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.30727107099665,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.30824199599738,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.30879981099861,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.30976049599849,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.33128387400211,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.332473456001026,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.332943604997126,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.33386006799992,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.334354519000044,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.33913641599793,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.339698889998544,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.34051121799712,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.34098089100007,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.3620499719982,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.363354872002674,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.36426699299773,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.3647425320014,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.371730965001916,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.372411035998084,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.37322487899655,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.37375649200112,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.37468554700172,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.393791747999785,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.39871080800367,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.399383916999795,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.40035183299915,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.40251394199731,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.40368857199792,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.40422603899788,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.40499808300228,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.405473956001515,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.42675989599957,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.42736690399761,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.42826808599784,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.428767261997564,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.43427540599805,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.43478987999697,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.435733352998795,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.43621338200319,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.45659847599745,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.45724342599715,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.45811247600068,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.45862651799689,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.459460115002,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.466193900996586,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.4672620909987,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.46781972199824,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.468866468996566,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.48703289900004,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.488130022000405,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.48869512999954,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.48957631999656,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.49011811999662,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.499616898996464,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.50043584800005,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.50162192800053,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.50228766300279,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.51692036999884,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.51880692200211,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.522788444999605,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.523576311003126,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.52454675499757,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.52505032099725,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.5263725870027,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.530737874003535,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.547732482002175,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.550707763999526,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.55251659899659,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.55329030100256,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.554189973001485,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.554762799001765,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.562250782000774,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.56372782299877,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.57608494700253,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.5767022450018,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.5775171360001,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.57796071500343,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.584425679997366,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.58506723900064,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.58595163599966,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.589609417002066,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.590663317998406,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.60678207699675,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (37.60773870700359,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (37.60822527099663,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (37.60895882600016,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (37.609414222999476,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
# ...
#    'status': 'sleeping'}),
#  (39.25596990699705,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.261336476003635,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.26200088999758,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.26645931499661,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.26728615900356,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.271595757003524,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.27211516600073,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.273526509001385,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.27796171099908,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.283565913996426,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.284300491002796,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.300293574000534,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.30131319799693,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.30233419399883,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.30302856100025,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.306445654001436,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.306948621997435,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.32865332200163,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.33133963600267,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.33229728799779,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.33333593599673,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.34000686000218,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.34052113600046,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.343488653998065,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.34410937099892,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.35997783199855,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.36097870399681,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.36191687399696,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.363279120996594,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.36782994499663,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.368399239996506,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.369243134999124,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.37028065499908,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.3742748270015,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.39880069799983,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.40179197699763,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.40231255300023,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.41008506499929,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.41319124599977,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.42575594400114,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.42751305799902,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.434021975997894,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.434551332997216,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.43542640600208,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.43589309499657,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.44992485099647,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.45096005999949,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.455132151000726,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.45588029699866,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.456825984001625,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.457412588002626,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.45819167599984,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.48436723800114,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.48588695700164,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.48655736599903,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.48812353199901,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.49238477600011,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.493349383999885,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.49384597699827,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.494686065998394,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.5006962059997,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.515876432997175,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.51726603700081,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.5219297299991,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.5224671429969,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.52326303299924,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.529309170997294,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.53026013600174,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.53073823200248,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.54355926500284,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.54411756299669,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.544933276003576,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.546512850996805,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.5617162760027,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.56237164999766,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.56323887599865,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.56373716099915,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.56773821800016,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.58180051600357,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.58844484099973,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.592610942003375,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.59775372999866,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.59827322499768,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.59919539799739,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.59969802800333,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.61333074700087,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.61585089199798,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.62328607800009,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.62390432399843,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.626272424997296,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.638458282999636,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.640517261999776,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.64119368699903,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.645936644003086,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.65335939900251,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.658512064001116,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.66495424800087,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.67239185499784,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.676274197001476,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.680076188000385,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.6806356149973,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.681453254997905,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.681885847996455,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.68275979899772,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.68343095500313,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.704832185998384,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.70562465900002,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.706538347003516,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.707161366000946,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.708001763996435,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.708487099997,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.7309624949994,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.73156053000275,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.73250985499908,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.73302007900202,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.73459968200041,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.74024327599909,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.7416594469978,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.74218973200186,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.74373143599951,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.76214405799692,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.76308294900082,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.76366106200294,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.76459959299973,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.76510622299975,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.77162757900078,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.7723185520008,
#   {'_id': 3,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.77320072099974,
#   {'_id': 2,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.775565454998286,
#   {'_id': 3,
#    'battery': 2,
#    'neighbour': 1,
#    'nstat': 'sleeping',
#    'status': 'running'}),
#  (39.7925051630009,
#   {'_id': 2,
#    'battery': 2,
#    'neighbour': 2,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  (39.79305529099656,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 2,
#    'nstat': 'sleeping',
#    'status': 'pending'}),
#  (39.793953022002825,
#   {'_id': 2,
#    'battery': 3,
#    'neighbour': 1,
#    'nstat': 'pending',
#    'status': 'running'}),
#  (39.7944286369966,
#   {'_id': 3,
#    'battery': 1,
#    'neighbour': 3,
#    'nstat': 'running',
#    'status': 'sleeping'}),
#  ...]

# %%
rec = record[0:5000]
len([i for i in record if i[1]['status']=='sleeping' and i[1]['nstat']=='sleeping'])
# Out:
# 0

# %%
def time_sleeping(record):
    sleeper_indices = (ind for ind, el in enumerate(record) if
                       el[1]['status']=='sleeping' and el[1]['nstat']=='sleeping')
    times = (record[i+1][0]-record[i][0] for i in sleeper_indices)
    return sum(times)
def total_time(record):
    return record[-1][0]-record[0][0]
time_sleeping(record[0:480])/total_time(record[0:480])
# Out:
# 0.0

# %%
len(record)
# Out:
# 26404

# %%
357/5000
# Out:
# 0.0714

# %%
1804/25256
# Out:
# 0.07142857142857142
